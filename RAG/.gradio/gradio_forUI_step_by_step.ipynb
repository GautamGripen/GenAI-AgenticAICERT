# %%
#gradio is by google for developing frontend UI
# !pip install gradio
# Out:
# ...
#    ---------------------------------------- 0.0/54.2 MB ? eta -:--:--
#    --- ------------------------------------ 5.2/54.2 MB 39.8 MB/s eta 0:00:02
#    --- ------------------------------------ 5.2/54.2 MB 39.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 5.5/54.2 MB 9.6 MB/s eta 0:00:06
#    ------- -------------------------------- 10.0/54.2 MB 12.2 MB/s eta 0:00:04
#    -------- ------------------------------- 12.1/54.2 MB 12.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 13.6/54.2 MB 11.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 14.2/54.2 MB 10.2 MB/s eta 0:00:04
#    ---------- ----------------------------- 14.4/54.2 MB 9.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 14.9/54.2 MB 8.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 15.2/54.2 MB 7.7 MB/s eta 0:00:06
#    ----------- ---------------------------- 15.7/54.2 MB 7.1 MB/s eta 0:00:06
# ...
